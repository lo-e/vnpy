# %%
# %matplotlib inline

from datetime import datetime

import numpy as np
import matplotlib.pyplot as plt

from turtleEngine import BacktestingEngine

# %%
engine = BacktestingEngine()
engine.setPeriod(datetime(2014, 1, 1), datetime(2019, 12, 30))
engine.initPortfolio('setting.csv', 10000000)

engine.loadData()
engine.runBacktesting()
engine.showResult()
# Out:
# 投资组合的合约代码['RB99', 'HC99', 'J99', 'I99', 'AP99', 'TA99']
# 投资组合的初始价值10000000
# RB99数据加载完成，总数据量：1232
# HC99数据加载完成，总数据量：1187
# J99数据加载完成，总数据量：1238
# I99数据加载完成，总数据量：1238
# AP99数据加载完成，总数据量：267
# TA99数据加载完成，总数据量：1232
# 全部数据加载完成
# 开始回放K线数据
# K线数据回放结束
# 开始统计回测结果
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-8e441673beb2> in <module>()
#       5 engine.loadData()
#       6 engine.runBacktesting()
# ----> 7 engine.showResult()
#
# C:\Users\lo-e\Quant\vnpy\examples\TurtleStrategy\turtleEngine.pyc in showResult(self)
#     238     def showResult(self):
#     239         """显示回测结果"""
# --> 240         timeseries, result = self.calculateResult()
#     241
#     242         # 输出统计结果
#
# C:\Users\lo-e\Quant\vnpy\examples\TurtleStrategy\turtleEngine.pyc in calculateResult(self, annualDays)
#     137
#     138         for result in self.resultList:
# --> 139             result.calculatePnl()
#     140
#     141         resultList = self.resultList
#
# C:\Users\lo-e\Quant\vnpy\examples\TurtleStrategy\turtleEngine.pyc in calculatePnl(self)
#     425     #----------------------------------------------------------------------
#     426     def calculatePnl(self):
# --> 427         """计算总盈亏"""
#     428         self.calculateHoldingPnl()
#     429         self.calculateTradingPnl()
#
# C:\Users\lo-e\Quant\vnpy\examples\TurtleStrategy\turtleEngine.pyc in calculateHoldingPnl(self)
#     416         for vtSymbol, pos in self.posDict.items():
#     417             previousClose = self.previousCloseDict.get(vtSymbol, 0)
# --> 418             close = self.closeDict.get(vtSymbol, 0)
#     419             #close = self.closeDict[vtSymbol]
#     420             size = SIZE_DICT[vtSymbol]
#
# KeyError: 'HC99'

# %%
tradeList = engine.getTradeData('000300')
for trade in tradeList:
    print '%s %s %s %s@%s' %(trade.vtSymbol, trade.direction, trade.offset,
                             trade.volume, trade.price)
# Out:
# 000300 多 开仓 2837@2191.4
# 000300 多 开仓 2837@2209.2
# 000300 多 开仓 2837@2226.8
# 000300 多 开仓 2837@2244.4
# 000300 空 平仓 11348@2179.0
# 000300 空 开仓 3037@2134.4
# 000300 空 开仓 3037@2118.0
# 000300 空 开仓 3037@2101.4
# 000300 多 平仓 9111@2167.4
# 000300 多 开仓 3823@2178.0
# 000300 多 开仓 3823@2191.2
# 000300 空 平仓 7646@2138.8
# 000300 多 开仓 4766@2186.2
# 000300 多 开仓 4766@2196.6
# 000300 多 开仓 4766@2207.2
# 000300 多 开仓 4766@2217.6
# 000300 空 平仓 19064@2333.2
# 000300 多 开仓 3841@2380.8
# 000300 多 开仓 3841@2393.8
# 000300 多 开仓 3841@2406.8
# 000300 多 开仓 3841@2419.8
# 000300 空 平仓 15364@2374.2
# 000300 多 开仓 3222@2488.2
# 000300 多 开仓 3222@2503.6
# 000300 多 开仓 3222@2519.2
# 000300 多 开仓 3222@2534.6
# 000300 空 平仓 12888@3414.0
# 000300 多 开仓 1308@3608.6
# 000300 多 开仓 1308@3647.0
# 000300 多 开仓 1308@3685.2
# 000300 多 开仓 1308@3734.0
# 000300 空 平仓 5232@4511.8
# 000300 多 开仓 691@5255.0
# 000300 多 开仓 691@5299.2
# 000300 多 开仓 691@5379.4
# 000300 空 平仓 2073@5090.0
# 000300 空 开仓 657@4665.6
# 000300 空 开仓 657@4589.4
# 000300 空 开仓 657@4513.2
# 000300 多 平仓 1971@4817.8
# 000300 空 开仓 585@4455.4
# 000300 空 开仓 585@4369.8
# 000300 空 开仓 585@4284.2
# 000300 空 开仓 585@4198.8
# 000300 多 平仓 2340@4278.2
# 000300 空 开仓 583@3454.6
# 000300 空 开仓 583@3452.2
# 000300 空 开仓 583@3366.4
# 000300 空 开仓 583@3280.6
# 000300 多 平仓 2332@3426.6
# 000300 多 开仓 1293@3891.8
# 000300 空 平仓 1293@3737.2
# 000300 空 开仓 1369@3571.0
# 000300 空 开仓 1369@3534.4
# 000300 空 开仓 1369@3498.0
# 000300 空 开仓 1369@3382.2
# 000300 多 平仓 5476@3528.2
# 000300 空 开仓 1175@3377.2
# 000300 空 开仓 1175@3334.8
# 000300 空 开仓 1175@3292.2
# 000300 空 开仓 1175@3249.6
# 000300 多 平仓 4700@3042.0
# 000300 多 开仓 1169@3128.2
# 000300 多 开仓 1169@3171.0
# 000300 多 开仓 1169@3213.8
# 000300 多 开仓 1169@3256.6
# 000300 空 平仓 4676@3163.4
# 000300 空 开仓 1914@3107.4
# 000300 空 开仓 1914@3081.2
# 000300 空 开仓 1914@3055.2
# 000300 空 开仓 1914@3029.0
# 000300 多 平仓 7656@3105.2
# 000300 多 开仓 2407@3201.8
# 000300 多 开仓 2407@3222.6
# 000300 多 开仓 2407@3243.2
# 000300 多 开仓 2407@3264.0
# 000300 空 平仓 9628@3218.2
# 000300 多 开仓 2688@3285.0
# 000300 多 开仓 2688@3303.6
# 000300 多 开仓 2688@3322.2
# 000300 多 开仓 2688@3340.8
# 000300 空 平仓 10752@3271.8
# 000300 空 开仓 2753@3234.6
# 000300 空 开仓 2753@3214.8
# 000300 多 平仓 5506@3287.6
# 000300 多 开仓 3238@3323.4
# 000300 多 开仓 3238@3336.8
# 000300 多 开仓 3238@3352.2
# 000300 多 开仓 3238@3367.6
# 000300 空 平仓 12952@3456.8
# 000300 空 开仓 3205@3267.0
# 000300 多 平仓 3205@3329.4
# 000300 多 开仓 3109@3373.4
# 000300 多 开仓 3109@3389.4
# 000300 多 开仓 3109@3405.6
# 000300 多 开仓 3109@3421.6
# 000300 空 平仓 12436@3419.6
# 000300 多 开仓 3692@3492.2
# 000300 多 开仓 3692@3505.6
# 000300 空 平仓 7384@3451.6
# 000300 多 开仓 3433@3508.0
# 000300 多 开仓 3433@3520.6
# 000300 空 平仓 6866@3462.2
# 000300 空 开仓 3420@3422.4
# 000300 空 开仓 3420@3407.8
# 000300 多 平仓 6840@3466.2
# 000300 空 开仓 3243@3404.0
# 000300 空 开仓 3243@3388.6
# 000300 空 开仓 3243@3373.2
# 000300 空 开仓 3243@3357.8
# 000300 多 平仓 12972@3419.4
# 000300 多 开仓 3098@3466.6
# 000300 多 开仓 3098@3482.8
# 000300 多 开仓 3098@3498.8
# 000300 多 开仓 3098@3515.0
# 000300 空 平仓 12392@3688.0
# 000300 多 开仓 2000@4087.0
# 000300 多 开仓 2000@4112.0
# 000300 多 开仓 2000@4137.0
# 000300 多 开仓 2000@4162.0
# 000300 空 平仓 8000@4232.8
# 000300 空 开仓 1475@3896.2
# 000300 空 开仓 1475@3896.2
# 000300 空 开仓 1475@3887.6
# 000300 空 开仓 1475@3853.8
# 000300 多 平仓 5900@4021.0
# 000300 空 开仓 1674@3896.8
# 000300 空 开仓 1674@3896.8
# 000300 空 开仓 1674@3896.8
# 000300 空 开仓 1674@3896.8
# 000300 多 平仓 6696@3937.0
# 000300 空 开仓 1598@3794.2
# 000300 空 开仓 1598@3763.0
# 000300 空 开仓 1598@3731.6
# 000300 多 平仓 4794@3854.4
# 000300 多 开仓 1903@3925.6
# 000300 空 平仓 1903@3841.8
# 000300 空 开仓 2058@3732.4
# 000300 多 平仓 2058@3829.6
# 000300 空 开仓 1988@3702.6
# 000300 空 开仓 1988@3697.0
# 000300 空 开仓 1988@3671.8
# 000300 空 开仓 1988@3646.6
# 000300 多 平仓 7952@3506.2
# 000300 空 开仓 1510@3312.8
# 000300 空 开仓 1510@3282.0
# 000300 多 平仓 3020@3414.6
# 000300 空 开仓 1458@3251.8
# 000300 空 开仓 1458@3223.4
# 000300 多 平仓 2916@3360.6
# 000300 空 开仓 1654@3209.0
# 000300 多 平仓 1654@3330.0
# 000300 多 开仓 1733@3416.6
# 000300 多 开仓 1733@3445.4
# 000300 空 平仓 3466@3330.0
# 000300 空 开仓 1692@3179.6
# 000300 空 开仓 1692@3161.8
# 000300 空 开仓 1692@3132.2
# 000300 空 开仓 1692@3102.8
# 000300 多 平仓 6768@3221.0
